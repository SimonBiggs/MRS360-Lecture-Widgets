# %% [markdown]
# # Widgets
#
#  * [Lecture 2 Series Widgets](Topic%201%20Widgets.ipynb)
#  * [Lecture 3 Radiation Physics Fluence](Fluence.ipynb)
#  * [Target models lecture](TargetModels.ipynb)
#
#
# ## Other notebooks
#
#  * [Plot's of Q4 in topic 1](Topic%201%20Questions.ipynb)
